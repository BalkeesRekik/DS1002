# %% [markdown]
# <a href="https://colab.research.google.com/github/BalkeesRekik/DS1002/blob/main/HW7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # More pandas exercises
#
# Create a Colab notebook. Complete the tasks as specified in the directions. Run each cell to return the desired output. Save your notebook back to your GitHub repository and submit the GitHub URL for your notebook for review.

# %% [markdown]
# 1.  Load the following dataset into Colab and perform the requested operations in code.
#
#  Source: https://ds1002-resources.s3.amazonaws.com/data/ride_sharing.csv

# %%
# Load pandas and the data
import pandas as pd

dataset = pd.read_csv('https://ds1002-resources.s3.amazonaws.com/data/ride_sharing.csv')

# %%
# show how many rows and columns are in this dataset
## 25760 rows and 10 columns

# %%
# The first column, "duration" is seen as a string.
# Using two snippets of code, clean this column up so that
# is now an integer (int64)

dataset['duration'] = dataset['duration'].str.replace(' minutes', '')
dataset['duration'] = dataset['duration'].astype(int)
dataset
# Out:
#        duration  station_A_id  \
# 0            12            81
# 1            24             3
# 2             8            67
# 3             4            16
# 4            11            22
# ...         ...           ...
# 25755        11            15
# 25756        10            15
# 25757        14            15
# 25758        14            15
# 25759        29            16
#
#                                           station_A_name  station_B_id  \
# 0                                     Berry St at 4th St           323
# 1           Powell St BART Station (Market St at 4th St)           118
# 2      San Francisco Caltrain Station 2  (Townsend St...            23
# 3                                Steuart St at Market St            28
# 4                                  Howard St at Beale St           350
# ...                                                  ...           ...
# 25755  San Francisco Ferry Building (Harry Bridges Pl...            34
# 25756  San Francisco Ferry Building (Harry Bridges Pl...            34
# 25757  San Francisco Ferry Building (Harry Bridges Pl...            42
# 25758  San Francisco Ferry Building (Harry Bridges Pl...            42
# 25759                            Steuart St at Market St           115
#
#                                       station_B_name  bike_id  user_type  \
# 0                                 Broadway at Kearny     5480          2
# 1                    Eureka Valley Recreation Center     5193          2
# 2                      The Embarcadero at Steuart St     3652          3
# 3                       The Embarcadero at Bryant St     1883          1
# 4                               8th St at Brannan St     4626          2
# ...                                              ...      ...        ...
# 25755                 Father Alfred E Boeddeker Park     5063          1
# 25756                 Father Alfred E Boeddeker Park     5411          2
# 25757  San Francisco City Hall (Polk St at Grove St)     5157          2
# 25758  San Francisco City Hall (Polk St at Grove St)     4438          2
# 25759                             Jackson Playground     1705          3
#
#        user_birth_year user_gender  tire_size
# 0                 1959        Male         26
# 1                 1965        Male         27
# 2                 1993        Male         29
# 3                 1979        Male         26
# 4                 1994        Male         27
# ...                ...         ...        ...
# 25755             2000        Male         26
# 25756             1998        Male         26
# 25757             1995        Male         26
# 25758             1995        Male         27
# 25759             1990        Male         27
#
# [25760 rows x 10 columns]
# Warning: total number of rows (25760) exceeds max_rows (20000). Limiting to first (20000) rows.
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dataset['duration'].plot(kind='hist', bins=20, title='duration')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dataset['station_A_id'].plot(kind='hist', bins=20, title='station_A_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dataset['station_B_id'].plot(kind='hist', bins=20, title='station_B_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dataset['bike_id'].plot(kind='hist', bins=20, title='bike_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# dataset.groupby('user_gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dataset.plot(kind='scatter', x='duration', y='station_A_id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dataset.plot(kind='scatter', x='station_A_id', y='station_B_id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dataset.plot(kind='scatter', x='station_B_id', y='bike_id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dataset.plot(kind='scatter', x='bike_id', y='user_type', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dataset['duration'].plot(kind='line', figsize=(8, 4), title='duration')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# dataset['station_A_id'].plot(kind='line', figsize=(8, 4), title='station_A_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# dataset['station_B_id'].plot(kind='line', figsize=(8, 4), title='station_B_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# dataset['bike_id'].plot(kind='line', figsize=(8, 4), title='bike_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(dataset['user_gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(dataset, x='duration', y='user_gender', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(dataset['user_gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(dataset, x='station_A_id', y='user_gender', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(dataset['user_gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(dataset, x='station_B_id', y='user_gender', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(dataset['user_gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(dataset, x='bike_id', y='user_gender', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# Warning: total number of rows (25760) exceeds max_rows (20000). Limiting to first (20000) rows.
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['duration'].plot(kind='hist', bins=20, title='duration')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['station_A_id'].plot(kind='hist', bins=20, title='station_A_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['station_B_id'].plot(kind='hist', bins=20, title='station_B_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('user_gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='index', y='duration', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='duration', y='station_A_id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='station_A_id', y='station_B_id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='station_B_id', y='bike_id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['duration']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('user_gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='user_gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('duration')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['station_A_id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('user_gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='user_gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('station_A_id')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['station_B_id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('user_gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='user_gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('station_B_id')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['bike_id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('user_gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='user_gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('bike_id')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['duration'].plot(kind='line', figsize=(8, 4), title='duration')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['station_A_id'].plot(kind='line', figsize=(8, 4), title='station_A_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['station_B_id'].plot(kind='line', figsize=(8, 4), title='station_B_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['user_gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='index', y='user_gender', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['user_gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='duration', y='user_gender', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['user_gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='station_A_id', y='user_gender', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['user_gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='station_B_id', y='user_gender', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# Now display the datatypes in the updated dataframe
print(dataset.dtypes)
# Out:
# duration            int64
# station_A_id        int64
# station_A_name     object
# station_B_id        int64
# station_B_name     object
# bike_id             int64
# user_type           int64
# user_birth_year     int64
# user_gender        object
# tire_size           int64
# dtype: object

# %%
# Show the min and max values of ride durations (the shortest and longest rides)
# Hint: If 'df' is the name of your dataframe, simply specify the column name
# and then append the .min() or .max() methods.
shortest_ride = dataset['duration'].min()
longest_ride= dataset['duration'].max()

print("The shortest ride: ", shortest_ride, "minute")
print("The longest ride: ", longest_ride, "minutes")
# Out:
# The shortest ride:  1 minute(s)
# The longest ride:  1372 minute(s)

# %%
# Create a new dataframe object and populate it with rides that are 60 minutes or less.
# Hint: Use the .query() method for the dataframe that we used in class.
df= dataset.query('duration <= 60')
print(df)
# Out:
#        duration  station_A_id  \
# 0            12            81
# 1            24             3
# 2             8            67
# 3             4            16
# 4            11            22
# ...         ...           ...
# 25755        11            15
# 25756        10            15
# 25757        14            15
# 25758        14            15
# 25759        29            16
#
#                                           station_A_name  station_B_id  \
# 0                                     Berry St at 4th St           323
# 1           Powell St BART Station (Market St at 4th St)           118
# 2      San Francisco Caltrain Station 2  (Townsend St...            23
# 3                                Steuart St at Market St            28
# 4                                  Howard St at Beale St           350
# ...                                                  ...           ...
# 25755  San Francisco Ferry Building (Harry Bridges Pl...            34
# 25756  San Francisco Ferry Building (Harry Bridges Pl...            34
# 25757  San Francisco Ferry Building (Harry Bridges Pl...            42
# 25758  San Francisco Ferry Building (Harry Bridges Pl...            42
# 25759                            Steuart St at Market St           115
#
#                                       station_B_name  bike_id  user_type  \
# 0                                 Broadway at Kearny     5480          2
# 1                    Eureka Valley Recreation Center     5193          2
# 2                      The Embarcadero at Steuart St     3652          3
# 3                       The Embarcadero at Bryant St     1883          1
# 4                               8th St at Brannan St     4626          2
# ...                                              ...      ...        ...
# 25755                 Father Alfred E Boeddeker Park     5063          1
# 25756                 Father Alfred E Boeddeker Park     5411          2
# 25757  San Francisco City Hall (Polk St at Grove St)     5157          2
# 25758  San Francisco City Hall (Polk St at Grove St)     4438          2
# 25759                             Jackson Playground     1705          3
#
#        user_birth_year user_gender  tire_size
# 0                 1959        Male         26
# 1                 1965        Male         27
# 2                 1993        Male         29
# 3                 1979        Male         26
# 4                 1994        Male         27
# ...                ...         ...        ...
# 25755             2000        Male         26
# 25756             1998        Male         26
# 25757             1995        Male         26
# 25758             1995        Male         27
# 25759             1990        Male         27
#
# [25544 rows x 10 columns]

# %%
# Now show both the min and max values of the duration column for your new dataset.
shortest_ride_df = df['duration'].min()
longest_ride_df= df['duration'].max()

print("The shortest ride: ", shortest_ride_df, "minute")
print("The longest ride: ", longest_ride_df, "minutes")
# Out:
# The shortest ride:  1 minute
# The longest ride:  60 minutes

# %%
# Using the new dataframe, update it so that is ONLY has records where
# the tire_size is 26.
df= df.query('tire_size == 26')
print(df)
# Out:
#        duration  station_A_id  \
# 0            12            81
# 3             4            16
# 6            16            67
# 9             5            30
# 12            7             3
# ...         ...           ...
# 25750        15            16
# 25751        15            16
# 25755        11            15
# 25756        10            15
# 25757        14            15
#
#                                           station_A_name  station_B_id  \
# 0                                     Berry St at 4th St           323
# 3                                Steuart St at Market St            28
# 6      San Francisco Caltrain Station 2  (Townsend St...           107
# 9         San Francisco Caltrain (Townsend St at 4th St)            62
# 12          Powell St BART Station (Market St at 4th St)            27
# ...                                                  ...           ...
# 25750                            Steuart St at Market St           371
# 25751                            Steuart St at Market St           371
# 25755  San Francisco Ferry Building (Harry Bridges Pl...            34
# 25756  San Francisco Ferry Building (Harry Bridges Pl...            34
# 25757  San Francisco Ferry Building (Harry Bridges Pl...            42
#
#                                       station_B_name  bike_id  user_type  \
# 0                                 Broadway at Kearny     5480          2
# 3                       The Embarcadero at Bryant St     1883          1
# 6                              17th St at Dolores St     1035          2
# 9                        Victoria Manalo Draves Park      333          1
# 12                           Beale St at Harrison St     1863          3
# ...                                              ...      ...        ...
# 25750                     Lombard St at Columbus Ave     4372          2
# 25751                     Lombard St at Columbus Ave     5246          1
# 25755                 Father Alfred E Boeddeker Park     5063          1
# 25756                 Father Alfred E Boeddeker Park     5411          2
# 25757  San Francisco City Hall (Polk St at Grove St)     5157          2
#
#        user_birth_year user_gender  tire_size
# 0                 1959        Male         26
# 3                 1979        Male         26
# 6                 1981        Male         26
# 9                 1994        Male         26
# 12                1998        Male         26
# ...                ...         ...        ...
# 25750             1994        Male         26
# 25751             1995        Male         26
# 25755             2000        Male         26
# 25756             1998        Male         26
# 25757             1995        Male         26
#
# [12761 rows x 10 columns]

# %%
# Finally, produce a count of all records with FEMALE riders
# using the 26-inch wheeled rental bikes for their rentals of
# one hour or less.
female_count = len(df.query('user_gender == "Female"'))
print(female_count)
# Out:
# 2962

# %% [markdown]
# 2. Find the file `more-messy-data.csv` on GitHub and upload it into Google Colab.
#
# Create a new Pandas DataFrame from that data and perform the following steps.

# %%
import pandas as pd
more_messy_data = pd.read_csv('/content/more-messy-data.csv')
more_messy_data
# Out:
#        id  sepal_length  sepal_width  petal_length petal_width     species
# 0       1           3.5          2.9           1.4         0.5   virginica
# 1       2           3.6          3.2           3.0         0.5      setosa
# 2       3           3.8          NaN           2.2         1.5      setosa
# 3       4           5.8          2.7           2.6         1.2   virginica
# 4       5           4.9          3.6           3.0         1.2   virginica
# ...   ...           ...          ...           ...         ...         ...
# 1311  412           NaN          3.6           2.9         0.5  Versicolor
# 1312  413           5.8          2.7           2.0         0.1  Versicolor
# 1313  414           3.3          3.7           1.3         2.8  Versicolor
# 1314  415           3.1          NaN           1.1         NaN  Versicolor
# 1315  416           4.3          2.5           1.3           1  Versicolor
#
# [1316 rows x 6 columns]

# %%
# Write a snippet of code that will display the number of duplicate rows exist in the DF.
duplicates = more_messy_data.duplicated().sum()
duplicates
# Out:
# 287

# %%
# Next, remove all duplicate rows using Python.
drop_all = more_messy_data.drop_duplicates()
drop_all
# Out:
#        id  sepal_length  sepal_width  petal_length petal_width     species
# 0       1           3.5          2.9           1.4         0.5   virginica
# 1       2           3.6          3.2           3.0         0.5      setosa
# 2       3           3.8          NaN           2.2         1.5      setosa
# 3       4           5.8          2.7           2.6         1.2   virginica
# 4       5           4.9          3.6           3.0         1.2   virginica
# ...   ...           ...          ...           ...         ...         ...
# 1311  412           NaN          3.6           2.9         0.5  Versicolor
# 1312  413           5.8          2.7           2.0         0.1  Versicolor
# 1313  414           3.3          3.7           1.3         2.8  Versicolor
# 1314  415           3.1          NaN           1.1         NaN  Versicolor
# 1315  416           4.3          2.5           1.3           1  Versicolor
#
# [1029 rows x 6 columns]

# %%
# For the FOUR columns involving sepal and petal length and width, update all NaN
# values with the column mean.

# The code did't work initially so I had to convert the data to numeric.
more_messy_data['sepal_length'] = pd.to_numeric(more_messy_data['sepal_length'])
more_messy_data['sepal_width'] = pd.to_numeric(more_messy_data['sepal_width'])
more_messy_data['petal_length'] = pd.to_numeric(more_messy_data['petal_length'])
more_messy_data['petal_width'] = pd.to_numeric(more_messy_data['petal_width'])

more_messy_data['sepal_length'].fillna(more_messy_data['sepal_length'].mean())
more_messy_data['sepal_width'].fillna(more_messy_data['sepal_width'].mean())
more_messy_data['petal_length'].fillna(more_messy_data['petal_length'].mean())
more_messy_data['petal_width'].fillna(more_messy_data['petal_width'].mean())

more_messy_data
# Out:
#        id  sepal_length  sepal_width  petal_length  petal_width     species
# 0       1      3.500000     2.900000           1.4      0.50000   virginica
# 1       2      3.600000     3.200000           3.0      0.50000      setosa
# 2       3      3.800000     2.992747           2.2      1.50000      setosa
# 3       4      5.800000     2.700000           2.6      1.20000   virginica
# 4       5      4.900000     3.600000           3.0      1.20000   virginica
# ...   ...           ...          ...           ...          ...         ...
# 1311  412      4.529662     3.600000           2.9      0.50000  Versicolor
# 1312  413      5.800000     2.700000           2.0      0.10000  Versicolor
# 1313  414      3.300000     3.700000           1.3      2.80000  Versicolor
# 1314  415      3.100000     2.992747           1.1      1.55706  Versicolor
# 1315  416      4.300000     2.500000           1.3      1.00000  Versicolor
#
# [1316 rows x 6 columns]

# %%
# Find any values in the dataframe that are still missing, and delete them.
more_messy_data = more_messy_data.dropna()
more_messy_data
# Out:
#        id  sepal_length  sepal_width  petal_length  petal_width     species
# 0       1      3.500000     2.900000           1.4      0.50000   virginica
# 1       2      3.600000     3.200000           3.0      0.50000      setosa
# 2       3      3.800000     2.992747           2.2      1.50000      setosa
# 3       4      5.800000     2.700000           2.6      1.20000   virginica
# 4       5      4.900000     3.600000           3.0      1.20000   virginica
# ...   ...           ...          ...           ...          ...         ...
# 1311  412      4.529662     3.600000           2.9      0.50000  Versicolor
# 1312  413      5.800000     2.700000           2.0      0.10000  Versicolor
# 1313  414      3.300000     3.700000           1.3      2.80000  Versicolor
# 1314  415      3.100000     2.992747           1.1      1.55706  Versicolor
# 1315  416      4.300000     2.500000           1.3      1.00000  Versicolor
#
# [1316 rows x 6 columns]

# %%
# How many different species are there?
diff_species = more_messy_data['species'].unique()
len(diff_species)
# Out:
# 8

# %%
# Clean up the 'species' variable so that there are exactly three different values.

more_messy_data['species'].dropna()
mapping = {'setosa': 'Setosa', 'versicolor': 'Versicolor', 'virginica': 'Virginica',
    'setoso': 'Setosa', 'Viginica': 'Virginica', 'Virginia': 'Virginica', 'Setosan': 'Setosa'}
more_messy_data['species'] = more_messy_data['species'].replace(mapping)
more_messy_data.dropna(subset=['species'])
print(more_messy_data['species'].unique())
# Out:
# ['Virginica' 'Setosa' 'Versicolor']

# %% [markdown]
# 3. Bonus:  Regular expressions
#
# Ordinary (non-vanity) Virginia license plates have the form `ABC1234`, meaning they have three upper case letters followed by four digits.  Write a regular expression that matches any string of this form (and doesn't match anything else).  Test your expression with code to make sure it works.
#
# To figure out out how to do this, start with the sample code below.  The `re` package has various functions related to regular expressions, including for example `match()`, which takes two arguments, first the regular expression and second the test string, and tests to see whether the *beginning* of the `test` string matches the pattern `exp`.
#
# Note that `re.match(exp,test)` does not return a boolean variable, as you might expect (in other words, a match doesn't return `True` and a non-match `False`).  The type of object you get is called `re.Match`, which is a data type special to the `re` package.  (The reason for this is that the object contains more information than just whether there is a match or not.) However, you can turn it into a boolean using `bool()` if you want.
#
# Include the following in the notebook you submit:
#
#  1. A regular expression in a text chunk
#  2. One or more code chunks in which you test several strings to verify that your regex is correct.
#  3. Make sure you display the results of testing various strings.
#
#  See this [documentation page](https://docs.python.org/3/howto/regex.html#regex-howto) for further help.

# %%
# Sample code for testing whether a string matches a regex

# First import this package for working with regular expressions
import re

# Here is an example.
# Play around with different expressions and test strings to see what happens.
exp = 'ab+'
test = 'aabbbc'

if re.match(exp,test):
  print("match!")
else:
  print("no match")

# uncomment this line if you want
# print(type(re.match(exp,test)))

# uncomment this line if you want
# print(bool(re.match(exp,test)))
# Out:
# no match

# %% [markdown]
# Regular expression: ^[A-Z]{3}\d{4}$

# %%
import re

exp = '^[A-Z]{3}\d{4}$'
test = 'XYZ6789'

if re.match(exp,test):
  print("match!")
else:
  print("no match")
# Out:
# match!

# %%
import re

exp = '^[A-Z]{3}\d{4}$'
test = 'AbC12345'

if re.match(exp,test):
  print("match!")
else:
  print("no match")
# Out:
# no match

# %%
import re

exp = '^[A-Z]{3}\d{4}$'
test = 'ABC 1234'

if re.match(exp,test):
  print("match!")
else:
  print("no match")
# Out:
# no match

# %% [markdown]
# Citations:
#
# [.query()](https://https://www.geeksforgeeks.org/pandas-query-method/)
#
# [pd.to_numeric](https://https://saturncloud.io/blog/pandas-tips-change-column-type/#:~:text=To%20convert%20one%20or%20more,depending%20on%20the%20input%20data.)
